# %%
print("Hello Manitoba, I'm coming Sept 2026 🇨🇦")
print("Bonjour Montreal, j'arrive en septembre 2026")
# Out:
# Hello Manitoba, I'm coming Sept 2026 🇨🇦
# Bonjour Montreal, j'arrive en septembre 2026
