# %%
# Day 2 Challenge: Canada Relocation Variables
# 1. Create variables for your data
your_name = "Rufus"  # change to your name
target_city = "Manitoba"  # or Montreal, Vancouver, etc
relocation_month = "September"
relocation_year = 2026
ielts_score = 8.5  # put your target

# 2. Use f-strings to print a sentence about yourself
print(f"My name is {your_name} and I will relocate to {target_city} in {relocation_month} {relocation_year}")

# 3. Do simple math with variables
years_to_go = relocation_year - 2026  # should be 0 since we're in 2026
months_of_prep = 4  # Apr to Aug
print(f"I have {months_of_prep} months to prepare for Canada")

# 4. Bonus: if/else preview for tomorrow
if ielts_score >= 8:
    print("Ready for Express Entry CLB 9")
else:
    print("More IELTS practice needed")
# Out:
# My name is Rufus and I will relocate to Manitoba in September 2026
# I have 4 months to prepare for Canada
# Ready for Express Entry CLB 9
